# %%
import pandas as pd

# %%
def final_database():
    crypto_table = pd.read_csv("data/crypto_table_2.csv",encoding = "ISO-8859-1", dtype=str)
    tweets_table = pd.read_csv("data/tweets_table.csv",encoding = "ISO-8859-1", dtype=str)
    
    final_table = crypto_table.set_index('date').join(tweets_table.set_index('date'))
    
    final_table.to_csv('data/final_table.csv', index=False)
    
    return final_table

# %%
final_database()
# Out:
#                  open      max_v      min_v      close          volume  \
# date
# 2021-01-03  26.476,66  28.519,63  26.413,13  26.760,72  64.216.240.796
# 2021-01-03     638,25     821,88     635,82     796,33  36.898.177.858
# 2021-01-03     292,25     353,57     292,25     344,32   5.937.217.755
# 2021-01-03      56,83      60,42      55,20      59,24      86.448.546
# 2021-01-03      31,52      33,98      31,16      33,59     618.779.865
# ...               ...        ...        ...        ...             ...
# 2021-04-12     577,22     588,12     563,67     573,42   2.553.924.096
# 2021-04-12     362,87     368,96     350,19     361,31     188.206.176
# 2021-04-12     473,94     533,57     433,95     492,99  10.819.201.024
# 2021-04-12     215,08     217,27     206,22     210,90   4.680.763.904
# 2021-04-12      98,22     105,68      97,26      98,31     172.691.888
#
#                   crypto                         tweet key_tweets
# date
# 2021-01-03       bitcoin  @RGVaerialphotos @SpaceX Yes          0
# 2021-01-03      ethereum  @RGVaerialphotos @SpaceX Yes          0
# 2021-01-03   bitcoincash  @RGVaerialphotos @SpaceX Yes          0
# 2021-01-03        kusama  @RGVaerialphotos @SpaceX Yes          0
# 2021-01-03  binance_coin  @RGVaerialphotos @SpaceX Yes          0
# ...                  ...                           ...        ...
# 2021-04-12   bitcoincash                           NaN        NaN
# 2021-04-12        kusama                           NaN        NaN
# 2021-04-12  binance_coin                           NaN        NaN
# 2021-04-12     lite_coin                           NaN        NaN
# 2021-04-12  bitcoin_gold                           NaN        NaN
#
# [4242 rows x 8 columns]
